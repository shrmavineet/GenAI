# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="openai/gpt-oss-20b")

from langchain_community.utilities import GoogleSerperAPIWrapper

search = GoogleSerperAPIWrapper()
# Out:
# C:\Users\vsharma\AppData\Local\Temp\ipykernel_25664\2045486483.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import GoogleSerperAPIWrapper

# %%
from langgraph.checkpoint.memory import MemorySaver

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    tools=[search.run],
    system_prompt="You are a agent and you can search anything on google",
    checkpointer= MemorySaver()
)

question = "Contact details of TechSim Plus Learnings"

response = agent.invoke(
    {"messages":[{"role":"user","content":question}]},
    {"configurable":{"thread_id": "Vineet"}},
)

print(response["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from langchain.agents import create_agent
#       3 agent = create_agent(
# ----> 4     model=model,
#       5     tools=[search.run],
#       6     system_prompt="You are a agent and you can search anything on google",
#       7     checkpointer= MemorySaver()
#       8 )
#      10 question = "Contact details of TechSim Plus Learnings"
#      12 response = agent.invoke(
#      13     {"messages":[{"role":"user","content":question}]},
#      14     {"configurable":{"thread_id": "Vineet"}},
#      15 )
#
# NameError: name 'model' is not defined
