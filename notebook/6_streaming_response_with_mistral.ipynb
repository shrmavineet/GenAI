# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_mistralai import ChatMistralAI

llm = ChatMistralAI(model="mistral-small-latest", streaming=True)

message = "How to sort two array in python?"

response = llm.stream(message)

for chunk in response:
    print(chunk.content, end="")
# Out:
# # Sorting Two Arrays in Python
#
# There are several ways to sort two arrays in Python while maintaining their relationships. Here are the most common approaches:
#
# ## Method 1: Sort both arrays together (using zip)
#
# ```python
# array1 = [3, 1, 4, 2]
# array2 = ['c', 'a', 'd', 'b']
#
# # Combine and sort
# combined = sorted(zip(array1, array2))
# sorted_array1 = [x for x, y in combined]
# sorted_array2 = [y for x, y in combined]
#
# print(sorted_array1)  # [1, 2, 3, 4]
# print(sorted_array2)  # ['a', 'b', 'c', 'd']
# ```
#
# ## Method 2: Sort one array and rearrange the other accordingly
#
# ```python
# array1 = [3, 1, 4, 2]
# array2 = ['c', 'a', 'd', 'b']
#
# # Sort array1 and get the indices
# sorted_indices = sorted(range(len(array1)), key=lambda i: array1[i])
#
# # Rearrange both arrays
# sorted_array1 = [array1[i] for i in sorted_indices]
# sorted_array2 = [array2[i] for i in sorted_indices]
#
# print(sorted_array1)  # [1, 2, 3, 4]
# ...
